# %%
#name = Kishan Dongare

#topic = Adaline in soft computing

class Adaline :
    def __init__(self) :
        pass


#Adaline training with AND logic
    def AdalAND(self) :

        w1 = float(input('Enter w1 :'))
        w2 = float(input('Enter w2 :'))
        b = float(input('Enter bias :'))
        eta = float(input('Enter learning rate :'))
        
        iters = int(input('Enter the number of iterations :'))

        x1 = [1, 1, -1, -1]
        x2 = [1, -1, 1, -1]
        y = [1, -1, -1, -1] #target


        w1n=0
        w2n=0
        w3n=0
        bn=0
        error=0

        for i in range(0, iters) :
            print ("\n Epoch "+str(i))
            for j in range(0, 4) :
                yin = x1[j]*w1 + x2[j]*w2 + b

                w1n = w1 + eta * x1[j] * (y[j] - yin)
                w2n = w2 + eta * x2[j] * (y[j] - yin)
                bn = b + eta * (y[j] - yin)
                error = (y[j]-yin)**2

                print ("\t[+] Weights and bias after iteration "+str(j)+" :")
                print ("\n\t\tW1 :" +str(w1n))
                print ("\t\tW2 :" +str(w2n))
                print ("\t\tb  :" +str(bn))
                print ("\t\terror :"+str(error))

                w1 = w1n
                w2 = w2n
                b = bn

            print ("\n\n[+] After epoch " +str(i)+ " :")
            print (w1, w2, b,error)

        print ("\n")
        print ("Final Weights :")
        print (w1, w2, b,error)



#Adaline training with OR logic.
    def AdalOR(self) :
        w1 = float(input('Enter w1 :'))
        w2 = float(input('Enter w2 :'))
        b = float(input('Enter bias :'))
        eta = float(input('Enter learning rate :'))

        iters = int(input('Enter the number of iterations :'))

        x1 = [1, 1, -1, -1]
        x2 = [1, -1, 1, -1]
        y = [1, 1, 1, -1]


        w1n=0
        w2n=0
        w3n=0
        bn=0
        error=0

        for i in range(0, iters) :
            print ("\n Epoch "+str(i))
            for j in range(0, 4) :
                yin = x1[j]*w1 + x2[j]*w2 + b

                w1n = w1 + eta * x1[j] * (y[j] - yin)
                w2n = w2 + eta * x2[j] * (y[j] - yin)
                bn = b + eta * (y[j] - yin)
                error = (y[j]-yin)**2

                print ("\t[+] Weights and bias after iteration "+str(j)+" :")
                print ("\n\t\tW1 :" +str(w1n))
                print ("\t\tW2 :" +str(w2n))
                print ("\t\tb  :" +str(bn))
                print ("\t\terror :"+str(error))

                w1 = w1n
                w2 = w2n
                b = bn

            print ("\n\n[+] After epoch " +str(i)+ " :")
            print (w1, w2, b,error)

        print ("\n")
        print ("Final Weights :")
        print (w1, w2, b, error)



def main() :
    adal = Adaline()

    print ("[+] Choose :")
    print ("\t1. AND")
    print ("\t2. OR")

    ch = int(input())

    if ch == 1 :
        adal.AdalAND()

    if ch == 2 :
        adal.AdalOR()

if __name__ == '__main__' :
    main()
# Out:
# [+] Choose :
# 	1. AND
# 	2. OR
# 2
# Enter w1 :0.1
# Enter w2 :0.1
# Enter bias :0.1
# Enter learning rate :0.1
# Enter the number of iterations :5
#
#  Epoch 0
# 	[+] Weights and bias after iteration 0 :
#
# 		W1 :0.16999999999999998
# 		W2 :0.16999999999999998
# 		b  :0.16999999999999998
# 		error :0.48999999999999994
# 	[+] Weights and bias after iteration 1 :
#
# 		W1 :0.253
# 		W2 :0.08699999999999997
# 		b  :0.253
# 		error :0.6889000000000001
# 	[+] Weights and bias after iteration 2 :
#
# 		W1 :0.1617
# 		W2 :0.17829999999999996
# 		b  :0.3443
# 		error :0.8335690000000001
# 	[+] Weights and bias after iteration 3 :
#
# 		W1 :0.26213000000000003
# 		W2 :0.27873
# 		b  :0.24386999999999998
# 		error :1.00861849
#
#
# [+] After epoch 0 :
# 0.26213000000000003 0.27873 0.24386999999999998 1.00861849
#
#  Epoch 1
# 	[+] Weights and bias after iteration 0 :
#
# 		W1 :0.28365700000000005
# 		W2 :0.300257
# 		b  :0.265397
# 		error :0.04634117290000003
# 	[+] Weights and bias after iteration 1 :
#
# 		W1 :0.3587773000000001
# 		W2 :0.2251367
# 		b  :0.3405173
# 		error :0.564305947209
# 	[+] Weights and bias after iteration 2 :
#
# 		W1 :0.27946497000000003
# 		W2 :0.30444903
# 		b  :0.41982963000000006
# 		error :0.6290445690028902
# 	[+] Weights and bias after iteration 3 :
#
# 		W1 :0.36305653300000007
# 		W2 :0.38804059300000004
# 		b  :0.33623806700000003
# 		error :0.6987549404782969
#
#
# [+] After epoch 1 :
# 0.36305653300000007 0.38804059300000004 0.33623806700000003 0.6987549404782969
#
#  Epoch 2
# 	[+] Weights and bias after iteration 0 :
#
# 		W1 :0.3543230137000001
# 		W2 :0.37930707370000005
# 		b  :0.32750454770000004
# 		error :0.007627435936347274
# 	[+] Weights and bias after iteration 1 :
#
# 		W1 :0.42407096493000007
# 		W2 :0.30955912247000006
# 		b  :0.39725249893000003
# 		error :0.48647767007824577
# 	[+] Weights and bias after iteration 2 :
#
# 		W1 :0.35234503057700006
# 		W2 :0.38128505682300007
# 		b  :0.46897843328300004
# 		error :0.5144609658810865
# 	[+] Weights and bias after iteration 3 :
#
# 		W1 :0.4258798651653001
# 		W2 :0.4548198914113001
# 		b  :0.3954435986947
# 		error :0.5407371897928641
#
#
# [+] After epoch 2 :
# 0.4258798651653001 0.4548198914113001 0.3954435986947 0.5407371897928641
#
#  Epoch 3
# 	[+] Weights and bias after iteration 0 :
#
# 		W1 :0.3982655296381701
# 		W2 :0.4272055558841701
# 		b  :0.36782926316757003
# 		error :0.07625515266049152
# 	[+] Weights and bias after iteration 1 :
#
# 		W1 :0.4643766059460131
# 		W2 :0.36109447957632707
# 		b  :0.43394033947541305
# 		error :0.437067441058144
# 	[+] Weights and bias after iteration 2 :
#
# 		W1 :0.3974424272565858
# 		W2 :0.42802865826575437
# 		b  :0.5008745181648404
# 		error :0.4480184276828184
# 	[+] Weights and bias after iteration 3 :
#
# 		W1 :0.4649827705208358
# 		W2 :0.4955690015300044
# 		b  :0.4333341749005904
# 		error :0.45616979682527237
#
#
# [+] After epoch 3 :
# 0.4649827705208358 0.4955690015300044 0.4333341749005904 0.45616979682527237
#
#  Epoch 4
# 	[+] Weights and bias after iteration 0 :
#
# 		W1 :0.42559417582569276
# 		W2 :0.45618040683486133
# 		b  :0.39394558020544734
# 		error :0.15514613920582523
# 	[+] Weights and bias after iteration 1 :
#
# 		W1 :0.4892582409060649
# 		W2 :0.3925163417544892
# 		b  :0.4576096452858195
# 		error :0.4053113182557857
# 	[+] Weights and bias after iteration 2 :
#
# 		W1 :0.4253450155194893
# 		W2 :0.4564295671410648
# 		b  :0.5215228706723951
# 		error :0.40849003793152144
# 	[+] Weights and bias after iteration 3 :
#
# 		W1 :0.4893198443206734
# 		W2 :0.5204043959422489
# 		b  :0.457548041871211
# 		error :0.4092778720140815
#
#
# [+] After epoch 4 :
# 0.4893198443206734 0.5204043959422489 0.457548041871211 0.4092778720140815
#
#
# Final Weights :
# 0.4893198443206734 0.5204043959422489 0.457548041871211 0.4092778720140815
